# %%
# %pip install requests
# %pip install response
import requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 262.2 kB/s eta 0:00:0031m15.4 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 620.2 kB/s eta 0:00:001m666.9 kB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 249.6 kB/s eta 0:00:001m245.6 kB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 360.5 kB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.0/19.0 MB 1.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 3.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.2/309.2 kB 7.8 MB/s eta 0:00:000m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 4.1 MB/s eta 0:00:00m eta 0:00:010:01:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.4 MB/s eta 0:00:00m eta 0:00:010:01:01m
# ...

# %%
from requests import Response


def get_exchange_rate(base_currency, target_currency):
    url = f"https://v6.exchangerate-api.com/v6/214f0fa610f9c0f902fa5f24/latest/{base_currency}"
    response: Response = requests.get(url)
    return response.json()['conversion_rates'][target_currency]

# %%
response.json()['conversion_rates']
# Out:
# {'USD': 1,
#  'AED': 3.6725,
#  'AFN': 71.0212,
#  'ALL': 92.6436,
#  'AMD': 387.9728,
#  'ANG': 1.79,
#  'AOA': 878.0962,
#  'ARS': 921.75,
#  'AUD': 1.4745,
#  'AWG': 1.79,
#  'AZN': 1.7003,
#  'BAM': 1.7951,
#  'BBD': 2.0,
#  'BDT': 117.529,
#  'BGN': 1.7952,
#  'BHD': 0.376,
#  'BIF': 2876.8463,
#  'BMD': 1.0,
#  'BND': 1.3419,
#  'BOB': 6.9258,
#  'BRL': 5.4376,
#  'BSD': 1.0,
#  'BTN': 83.5386,
#  'BWP': 13.507,
#  'BYN': 3.26,
#  'BZD': 2.0,
#  'CAD': 1.3624,
#  'CDF': 2833.7387,
#  'CHF': 0.8947,
#  'CLP': 913.7551,
#  'CNY': 7.2677,
#  'COP': 3986.9048,
#  'CRC': 527.918,
#  'CUP': 24.0,
#  'CVE': 101.2061,
#  'CZK': 23.2668,
#  'DJF': 177.721,
#  'DKK': 6.8468,
#  'DOP': 59.0596,
#  'DZD': 134.3317,
#  'EGP': 47.999,
#  'ERN': 15.0,
#  'ETB': 57.8841,
#  'EUR': 0.9178,
#  'FJD': 2.2521,
#  'FKP': 0.771,
#  'FOK': 6.8468,
#  'GBP': 0.771,
#  'GEL': 2.726,
#  'GGP': 0.771,
#  'GHS': 15.4918,
#  'GIP': 0.771,
#  'GMD': 64.2926,
#  'GNF': 8641.8559,
#  'GTQ': 7.7608,
# ...

# %%
def convert_currency(amount, exchange_rate):
    return amount * exchange_rate

# %%
base_currency = 'USD'
target_currency = 'CAD'
amount = 1

# %%
exchange_rate = get_exchange_rate(base_currency, target_currency)

# %%
usd_amount = 100
cad_amount = usd_amount * exchange_rate

# %%
# %pip install currencies
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import currencies

# %%
list(currencies.MONEY_FORMATS.keys())
# Out:
# ['AED',
#  'AFN',
#  'ALL',
#  'AMD',
#  'ANG',
#  'AOA',
#  'ARS',
#  'AUD',
#  'AWG',
#  'AZN',
#  'BAM',
#  'BBD',
#  'BDT',
#  'BGN',
#  'BHD',
#  'BND',
#  'BOB',
#  'BRL',
#  'BSD',
#  'BTN',
#  'BWP',
#  'BYR',
#  'BZD',
#  'CAD',
#  'CHF',
#  'CLP',
#  'CNY',
#  'COP',
#  'CRC',
#  'CZK',
#  'DKK',
#  'DOP',
#  'DZD',
#  'EGP',
#  'ETB',
#  'EUR',
#  'FJD',
#  'GBP',
#  'GEL',
#  'GHS',
#  'GMD',
#  'GTQ',
#  'GYD',
#  'HKD',
#  'HNL',
#  'HRK',
#  'HUF',
#  'IDR',
#  'ILS',
#  'INR',
#  'ISK',
#  'JEP',
#  'JMD',
#  'JOD',
#  'JPY',
#  'KES',
#  'KGS',
#  'KHR',
#  'KRW',
#  'KWD',
#  'KYD',
#  'KZT',
#  'LBP',
#  'LKR',
#  'LTL',
#  'LVL',
#  'MAD',
#  'MDL',
#  'MGA',
#  'MKD',
#  'MMK',
#  'MNT',
#  'MOP',
#  'MUR',
#  'MVR',
#  'MXN',
#  'MYR',
#  'MZN',
#  'NAD',
#  'NGN',
#  'NIO',
#  'NOK',
#  'NPR',
#  'NZD',
#  'OMR',
#  'PEN',
#  'PGK',
#  'PHP',
#  'PKR',
#  'PLN',
#  'PYG',
#  'QAR',
#  'RON',
#  'RSD',
#  'RUB',
#  'RWF',
#  'SAR',
#  'SCR',
#  'SEK',
#  'SGD',
# ...

# %%
url = f"https://v6.exchangerate-api.com/v6/214f0fa610f9c0f902fa5f24/latest/USD"

# %%
response: Response = requests.get(url)

# %%
# Out:
# <Response [200]>

# %%
list(response.json()['conversion_rates'].keys())
# Out:
# ['USD',
#  'AED',
#  'AFN',
#  'ALL',
#  'AMD',
#  'ANG',
#  'AOA',
#  'ARS',
#  'AUD',
#  'AWG',
#  'AZN',
#  'BAM',
#  'BBD',
#  'BDT',
#  'BGN',
#  'BHD',
#  'BIF',
#  'BMD',
#  'BND',
#  'BOB',
#  'BRL',
#  'BSD',
#  'BTN',
#  'BWP',
#  'BYN',
#  'BZD',
#  'CAD',
#  'CDF',
#  'CHF',
#  'CLP',
#  'CNY',
#  'COP',
#  'CRC',
#  'CUP',
#  'CVE',
#  'CZK',
#  'DJF',
#  'DKK',
#  'DOP',
#  'DZD',
#  'EGP',
#  'ERN',
#  'ETB',
#  'EUR',
#  'FJD',
#  'FKP',
#  'FOK',
#  'GBP',
#  'GEL',
#  'GGP',
#  'GHS',
#  'GIP',
#  'GMD',
#  'GNF',
#  'GTQ',
#  'GYD',
#  'HKD',
#  'HNL',
#  'HRK',
#  'HTG',
#  'HUF',
#  'IDR',
#  'ILS',
#  'IMP',
#  'INR',
#  'IQD',
#  'IRR',
#  'ISK',
#  'JEP',
#  'JMD',
#  'JOD',
#  'JPY',
#  'KES',
#  'KGS',
#  'KHR',
#  'KID',
#  'KMF',
#  'KRW',
#  'KWD',
#  'KYD',
#  'KZT',
#  'LAK',
#  'LBP',
#  'LKR',
#  'LRD',
#  'LSL',
#  'LYD',
#  'MAD',
#  'MDL',
#  'MGA',
#  'MKD',
#  'MMK',
#  'MNT',
#  'MOP',
#  'MRU',
#  'MUR',
#  'MVR',
#  'MWK',
#  'MXN',
#  'MYR',
# ...
